# %% [markdown]
# <a href="https://colab.research.google.com/github/patcon/polis-client/blob/main/python/examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install git+http://github.com/patcon/polis-client.git@main
# Out:
# Collecting git+http://github.com/patcon/polis-client.git@main
#   Cloning http://github.com/patcon/polis-client.git (to revision main) to /tmp/pip-req-build-erd0d6ef
#   Running command git clone --filter=blob:none --quiet http://github.com/patcon/polis-client.git /tmp/pip-req-build-erd0d6ef
#   warning: redirecting to https://github.com/patcon/polis-client.git/
#   Resolved http://github.com/patcon/polis-client.git to commit bdd0504d8857b8f840bfb065effb0eed3eefe757
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: polis-client
#   Building wheel for polis-client (pyproject.toml) ... done
#   Created wheel for polis-client: filename=polis_client-0.1.0-py3-none-any.whl size=23600 sha256=fad805e4dc923acf1550a3e20fb012de463aeb0aa3eb82bf6505f452f81acc7c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d6oiolx2/wheels/4c/86/24/9a07a2b13c8d7e6f7a9bdc188478273303b093011d1367fb82
# Successfully built polis-client
# Installing collected packages: polis-client
# Successfully installed polis-client-0.1.0

# %% [markdown]
# ## Setup

# %%
from polis_client import PolisClient
from pprint import pprint

polis = PolisClient()

# %% [markdown]
# ## Interacting with the default Pol.is server

# %%
comments = polis.get_comments(conversation_id="2demo")
if isinstance(comments, list) and len(comments) > 0:
    pprint(comments[0].to_dict())
# Out:
# {'created': '1403054214174',
#  'is_meta': False,
#  'is_seed': False,
#  'lang': 'en',
#  'pid': 0,
#  'quote_src_url': None,
#  'tid': 0,
#  'txt': 'I imagine new businesses opening will run counter operations where '
#         'guests grab their own silverware and bus their own tables.\n'}

# %%
report = polis.get_report(report_id="r2dfw8eambusb8buvecjt")
if report:
    pprint(report.to_dict())
# Out:
# {'conversation_id': '6jrufhr6dp',
#  'created': '1544617883365',
#  'label_group_0': None,
#  'label_group_1': None,
#  'label_group_2': None,
#  'label_group_3': None,
#  'label_group_4': None,
#  'label_group_5': None,
#  'label_group_6': None,
#  'label_group_7': None,
#  'label_group_8': None,
#  'label_group_9': None,
#  'label_x_neg': None,
#  'label_x_pos': None,
#  'label_y_neg': None,
#  'label_y_pos': None,
#  'mod_level': -2,
#  'modified': '1544617883365',
#  'report_id': 'r2dfw8eambusb8buvecjt',
#  'report_name': None}

# %%
conversation = polis.get_conversation(conversation_id="2demo")
if conversation and not isinstance(conversation, str):
    pprint(conversation.to_dict())
# Out:
# {'auth_needed_to_vote': False,
#  'auth_needed_to_write': True,
#  'auth_opt_allow_3rdparty': True,
#  'auth_opt_fb': True,
#  'auth_opt_tw': True,
#  'bgcolor': None,
#  'context': 'polis_test',
#  'conversation_id': '2demo',
#  'course_id': None,
#  'created': '1403054152585',
#  'dataset_explanation': None,
#  'description': 'How do you think the new minimum wage law will affect '
#                 'Seattle? Will it be for the better or for the worse? Why?',
#  'email_domain': None,
#  'help_bgcolor': None,
#  'help_color': None,
#  'help_type': 1,
#  'importance_enabled': False,
#  'is_active': True,
#  'is_anon': False,
#  'is_curated': False,
#  'is_data_open': True,
#  'is_draft': False,
#  'is_mod': False,
#  'is_owner': False,
#  'is_public': True,
#  'link_url': None,
#  'modified': '1763691102328000',
#  'need_suzinvite': False,
#  'org_id': 125,
#  'owner': 125,
#  'owner_sees_participation_stats': False,
#  'ownername': 'Mike Bjorkegren',
#  'parent_url': None,
#  'participant_count': 6357,
#  'prioritize_seed': False,
#  'profanity_filter': True,
#  'site_id': 'polis_site_id_mike_all2',
#  'socialbtn_type': 1,
#  'spam_filter': True,
#  'strict_moderation': True,
#  'style_btn': '',
#  'subscribe_type': 1,
#  'topic': '$15/hour',
#  'translations': [],
#  'treevite_enabled': False,
#  'upvotes': 1,
#  'use_xid_whitelist': False,
#  'vis_type': 1,
#  'write_hint_type': 1,
#  'write_type': 1}

# %%
math = polis.get_math(conversation_id="2demo")
pprint(math.to_dict(), depth=1)
# Out:
# {'base-clusters': {...},
#  'comment-priorities': {...},
#  'consensus': {...},
#  'group-aware-consensus': {...},
#  'group-clusters': [...],
#  'group-votes': {...},
#  'in-conv': [...],
#  'lastModTimestamp': None,
#  'lastVoteTimestamp': 1763691102328,
#  'math_tick': 14077,
#  'meta-tids': [],
#  'mod-in': [...],
#  'mod-out': [...],
#  'n': 508,
#  'n-cmts': 74,
#  'pca': {...},
#  'repness': {...},
#  'tids': [...],
#  'user-vote-counts': {...},
#  'votes-base': {...}}

# %%
votes = polis.get_votes(conversation_id="2demo", pid=2)
if isinstance(votes, list) and len(votes) > 0:
    pprint([v.to_dict() for v in votes])
# Out:
# [{'conversation_id': '2demo',
#   'modified': '1403057436071',
#   'pid': 2,
#   'tid': 1,
#   'vote': 1,
#   'weight_x_32767': 0},
#  {'conversation_id': '2demo',
#   'modified': '1403057488565',
#   'pid': 2,
#   'tid': 3,
#   'vote': 1,
#   'weight_x_32767': 0},
#  {'conversation_id': '2demo',
#   'modified': '1403057464378',
#   'pid': 2,
#   'tid': 6,
#   'vote': 0,
#   'weight_x_32767': 0},
#  {'conversation_id': '2demo',
#   'modified': '1403057440156',
#   'pid': 2,
#   'tid': 11,
#   'vote': -1,
#   'weight_x_32767': 0}]

# %% [markdown]
# ## Interacting with a Polis fork

# %%
voxit = PolisClient(base_url="https://voxit.sitra.fi/api/v3")

conversation_voxit = voxit.get_conversation(conversation_id="2asfdaahhy")
pprint(conversation_voxit.to_dict())
# Out:
# {'auth_needed_to_vote': False,
#  'auth_needed_to_write': False,
#  'auth_opt_allow_3rdparty': False,
#  'auth_opt_fb': False,
#  'auth_opt_tw': False,
#  'bgcolor': None,
#  'branding_type': 1,
#  'context': None,
#  'conversation_id': '2asfdaahhy',
#  'course_id': None,
#  'created': '1746450266596',
#  'description': 'Kehityspolitiikan suunta on muuttumassa sekä Suomessa että '
#                 'maailmalla. Geopoliittiset jännitteet ja reaalipolitiikan '
#                 'nousu ovat syrjäyttäneet aiempaa enemmän arvopohjaisen '
#                 'politiikan. Nyt on entistä tärkeämpää keskustella arvoista, '
#                 'näkemyksistä ja ratkaisuista. Ota kantaa!',
#  'email_domain': None,
#  'help_bgcolor': None,
#  'help_color': None,
#  'help_type': 1,
#  'importance_enabled': False,
#  'is_active': False,
#  'is_anon': False,
#  'is_data_open': False,
#  'is_draft': True,
#  'is_mod': False,
#  'is_owner': False,
#  'is_public': True,
#  'is_slack': False,
#  'link_url': None,
#  'lti_users_only': False,
#  'modified': '1748844829381',
#  'org_id': 647,
#  'owner': 647,
#  'owner_sees_participation_stats': False,
#  'ownername': 'MikaValitalo',
#  'parent_url': None,
#  'participant_count': 108,
#  'prioritize_seed': False,
#  'profanity_filter': True,
#  'site_id': 'polis_site_id_AlEjmvEdgXB1v35AoZ',
#  'socialbtn_type': 0,
#  'spam_filter': True,
#  'strict_moderation': True,
#  'style_btn': None,
#  'subscribe_type': 0,
#  'topic': 'Mitä mieltä kansalaisjärjestöt?',
#  'translations': [],
#  'upvotes': 1,
#  'use_xid_whitelist': False,
#  'vis_type': 1,
#  'write_hint_type': 1,
#  'write_type': 1}
